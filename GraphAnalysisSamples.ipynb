# %%
import stanza
import graphviz
import os
import json

import networkx as nx
import pandas as pd
import numpy as np

from tuw_nlp.grammar.text_to_4lang import TextTo4lang
from tuw_nlp.graph.fourlang import FourLang
from tuw_nlp.text.pipeline import CachedStanzaPipeline, CustomStanzaPipeline
from graphviz import Source

# %%
config = {
    "lang": "en",
    "depth": 0,
    "substitute": False,
    "nr of samples": 100,
}
data = {
 "dir": "data"
}

# %%
text_to_4lang = TextTo4lang(config["lang"], config["lang"] + "_nlp_cache")

nlp = stanza.Pipeline(config["lang"])
# Out:
# 2021-11-08 15:06:09 WARNING: Can not find mwt: default from official model list. Ignoring it.
# 2021-11-08 15:06:09 INFO: Loading these models for language: en (English):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | ewt     |
# | pos       | ewt     |
# | lemma     | ewt     |
# | depparse  | ewt     |
# =======================
#
# 2021-11-08 15:06:09 INFO: Use device: gpu
# 2021-11-08 15:06:09 INFO: Loading: tokenize
# 2021-11-08 15:06:10 INFO: Loading: pos
# 2021-11-08 15:06:11 INFO: Loading: lemma
# 2021-11-08 15:06:11 INFO: Loading: depparse
# 2021-11-08 15:06:11 INFO: Done loading processors!
# WARNING:root:creating new NLP cache in en_nlp_cache
# WARNING:root:loading cache from file: cache/UD_FL.json
# WARNING:root:loaded cache from cache/UD_FL.json with interpretations: ['fl', 'ud']
# 2021-11-08 15:06:24 INFO: Loading these models for language: en (English):
# =========================
# | Processor | Package   |
# -------------------------
# | tokenize  | ewt       |
# | pos       | ewt       |
# | lemma     | ewt       |
# | depparse  | ewt       |
# | sentiment | sstplus   |
# | ner       | ontonotes |
# =========================
#
# INFO:stanza:Loading these models for language: en (English):
# =========================
# | Processor | Package   |
# -------------------------
# | tokenize  | ewt       |
# | pos       | ewt       |
# | lemma     | ewt       |
# | depparse  | ewt       |
# | sentiment | sstplus   |
# | ner       | ontonotes |
# =========================
#
# 2021-11-08 15:06:24 INFO: Use device: gpu
# INFO:stanza:Use device: gpu
# 2021-11-08 15:06:24 INFO: Loading: tokenize
# INFO:stanza:Loading: tokenize
# 2021-11-08 15:06:24 INFO: Loading: pos
# INFO:stanza:Loading: pos
# 2021-11-08 15:06:24 INFO: Loading: lemma
# INFO:stanza:Loading: lemma
# 2021-11-08 15:06:24 INFO: Loading: depparse
# INFO:stanza:Loading: depparse
# 2021-11-08 15:06:25 INFO: Loading: sentiment
# INFO:stanza:Loading: sentiment
# 2021-11-08 15:06:25 INFO: Loading: ner
# INFO:stanza:Loading: ner
# 2021-11-08 15:06:26 INFO: Done loading processors!
# INFO:stanza:Done loading processors!

# %%
GOLD_ATTRIBUTES = "gold_attributes"
GOLD = "labels_gold"
ANNOTATED_ATTRIBUTES = "annotated_attributes"

def create_input(directory, attribute):
    sentence = []
    label = []
    for filename in os.listdir(directory):
        with open(os.path.join(directory, filename), "rt") as f:
            doc = json.load(f)
            for sen in doc["sens"].values():
                if doc[GOLD]:
                    lab = attribute in sen[GOLD_ATTRIBUTES]
                else:
                    lab = attribute in sen[ANNOTATED_ATTRIBUTES]
                sentence.append(sen["text"])
                label.append(lab)
    return pd.DataFrame(data=list(zip(sentence,label)),columns=["Text","Label"])

# %%
#Load in Data for specific feature
train_data = create_input(os.path.join(data["dir"], "train"), "Planzeichen")

#Save the labels for later. In this case its just 0,1 conversion for Planzeichen
labels = train_data.Label*1

train_data_true = train_data[train_data["Label"] == True]
train_data_false = train_data[train_data["Label"] == False]
train_data_true = train_data_true[:config["nr of samples"]]
train_data_false = train_data_false[:config["nr of samples"]]
train_data = train_data_true
train_data = train_data.append(train_data_false)
train_data
# Out:
#                                                   Text  Label
# 10   Gemäß § 5 (4) der Bauordnung für Wien wird für...   True
# 12   Die mit Eklw/BB2 bezeichnete Fläche ist der Er...   True
# 13   Von der mit Eklw P BB3 bezeichneten Fläche dür...   True
# 31   Auf den mit G/BB1 bezeichneten Flächen ist die...   True
# 32   In den mit BB2 bezeichneten Bereichen sind die...   True
# ..                                                 ...    ...
# 123  Der bisher gültige Flächenwidmungsplan und Beb...  False
# 124  Die roten Planzeichen gelten als neu festgesetzt.  False
# 125  Für die rechtliche Bedeutung der roten Planzei...  False
# 126  Für die Querschnitte der Verkehrsflächen gemäß...  False
# 127  In der Schlossallee und der Mariahilfer Straße...  False
#
# [200 rows x 2 columns]

# %%
def create_fl(sentence, depth=config["depth"], substitute=config["substitute"]):
    fl_graphs = list(text_to_4lang(sentence, depth=int(depth), substitute=substitute))
    g = fl_graphs[0]
    for n in fl_graphs[1:]:
        g = nx.compose(g, n)
    fl = FourLang(g, 0)
    if int(depth):
        text_to_4lang.expand(fl, depth=int(depth), substitute=substitute)
    # sen = nlp(sentence).sentences[0]
    return fl

# %%
def visualize(sentence):
    dot = graphviz.Digraph()
    dot.node("0", "ROOT", shape="box")
    for token in sentence.tokens:
        for word in token.words:
            dot.node(str(word.id), word.text)
            dot.edge(str(word.head), str(word.id),
                     label=word.deprel)
    return dot

# %%
train_data["4lang"] = None
train_data
# Out:
#                                                   Text  Label 4lang
# 10   Gemäß § 5 (4) der Bauordnung für Wien wird für...   True  None
# 12   Die mit Eklw/BB2 bezeichnete Fläche ist der Er...   True  None
# 13   Von der mit Eklw P BB3 bezeichneten Fläche dür...   True  None
# 31   Auf den mit G/BB1 bezeichneten Flächen ist die...   True  None
# 32   In den mit BB2 bezeichneten Bereichen sind die...   True  None
# ..                                                 ...    ...   ...
# 123  Der bisher gültige Flächenwidmungsplan und Beb...  False  None
# 124  Die roten Planzeichen gelten als neu festgesetzt.  False  None
# 125  Für die rechtliche Bedeutung der roten Planzei...  False  None
# 126  Für die Querschnitte der Verkehrsflächen gemäß...  False  None
# 127  In der Schlossallee und der Mariahilfer Straße...  False  None
#
# [200 rows x 3 columns]

# %%
for index, row in train_data.iterrows():
    # print(f"{index}: {row['Text'][:30]}")
    if row["Text"] and row["Text"] != "":
        fl = create_fl(row["Text"])
    else:
        fl = None
    train_data.at[index, "4lang"] = fl
# Out:
# 10: Gemäß § 5 (4) der Bauordnung f
# 12: Die mit Eklw/BB2 bezeichnete F
# 13: Von der mit Eklw P BB3 bezeich
# 31: Auf den mit G/BB1 bezeichneten
# 32: In den mit BB2 bezeichneten Be
# 33: In den mit P/BB3 bezeichneten
# 34: In dem mit BB4 bezeichneten Be
# 37: Gemäß § 4 Abs. 3 der BO für Wi
# 54: Innerhalb der mit G bezeichnet
# 60: Auf den mit BB1 bezeichneten G
# 61: Auf den mit BB2 bezeichneten u
# 63: Auf der mit BB3 bezeichneten u
# 64: Auf den mit BB4 bezeichneten G
# 65: Auf den mit BB5 bezeichneten G
# 66: Auf den mit BB6 bezeichneten G
# 67: Auf den mit BB7 bezeichneten u
# 68: Auf den mit BB8 bezeichneten u
# 70: Die mit BB9 bezeichneten und a
# 82: Für die mit BB 6 bezeichnete F
# 88: Die Dächer der auf den mit der
# 100: Bestimmungen gemäß § 5 Abs. 4
# 101: Auf den mit G BB 2 bezeichnete
# 102: Auf den mit Esp BB 3 bezeichne
# 103: Auf den mit BB 4 bezeichneten
# 105: Auf den mit BB 5 bezeichneten
# 113: Gemäß § 5 (4) der Bauordnung f
# 114: Auf der mit Esp BB18 bezeichne
# 116: Auf der mit Esp BB19 bezeichne
# 131: In dem mit BB1 bezeichneten Be
# 133: Auf den als Bauland/gemischtes
# 134: Innerhalb der als Grünland/Sch
# 135: Auf der mit BB4 bezeichneten u
# 159: Innerhalb der mit BB1 bezeichn
# 162: Auf den mit BB2 bezeichneten u
# 163: Auf der mit BB3 bezeichneten u
# 164: Für die mit BB4 bezeichneten F
# 166: Innerhalb der mit BB5 bezeichn
# 167: Innerhalb der mit BB6 bezeichn
# 168: Auf der mit BB7 bezeichneten G
# 169: Auf den mit BB8 bezeichneten G
# 173: Auf der mit Ak öDg bezeichnete
# 175: Auf der mit öDg bezeichneten u
# 177: Auf den mit BB9 bezeichneten u
# 178: Die mit BB10 bezeichneten und
# 187: Gemäß § 5 (4) der Bauordnung f
# 217: l.Für die mit BB 3 bezeichnete
# 219: Für die mit BB 4 bezeichnete G
# 220: Für die mit BB 5 bezeichnete F
# 226: Die Dächer der auf den mit der
# 239: In den mit BB l bezeichneten T
# 240: Auf den mit G BB 2 bezeichnete
# 250: Auf der als GB I 5 m g festges
# 272: In den mit BB1 bezeichneten Be
# 273: Innerhalb der als Bauland gewi
# 274: In den mit BB3 bezeichneten Be
# 276: In den mit P bezeichneten Bere
# 277: In den mit BB4 bezeichneten Be
# 279: In dem mit BB5 bezeichneten Be
# 280: In diesem Bereich darf jener U
# 281: Für die mit BB6 bezeichneten F
# 283: In den mit BB7 bezeichneten Be
# 286: In den mit BB11 bezeichneten B
# 290: Für die mit BB8 bezeichneten B
# 291: Für die mit BB9 bezeichneten B
# 292: Für die mit BB10 bezeichneten
# 294: Für den mit BB12 bezeichneten
# 296: Für den mit BB13 bezeichneten
# 297: Für den mit BB14 bezeichneten
# 298: Für den mit BB15 bezeichneten
# 316: Auf den mit BB1 bezeichneten F
# 317: Die mit BB2 bezeichnete Fläche
# 345: Besondere Bestimmungen mit Pla
# 347: Gemäß dem Wiener Kleingartenge
# 361: Auf den mit BB1 bezeichneten F
# 362: Entlang der mit BB2 bezeichnet
# 363: Auf der mit BB3 bezeichneten G
# 364: Die mit BB4 bezeichnete Grundf
# 372: Bestimmungen ohne Bezeichnung
# 373: Für die Grundfläche mit der Wi
# 392: Gemäß § 5 (4) der Bauordnung f
# 393: Auf den mit BB1 bezeichneten B
# 394: In den mit BB2 bezeichneten Te
# 395: Auf den mit BB3 bezeichneten G
# 396: Auf den mit BB4 bezeichneten G
# 397: In der mit BB5 bezeichneten Gr
# 398: Auf den mit Esp BB6 bezeichnet
# 399: Die bebaute Fläche der mit BB6
# 419: Gemäß § 5 (4) der Bauordnung f
# 420: Auf den mit BB1 bezeichneten G
# 421: Auf der mit EKZ BB2 bezeichnet
# 423: Auf der mit EKZ BB3 bezeichnet
# 425: Auf der mit EKZ BB4 bezeichnet
# 427: Auf der mit EKZ BB5 bezeichnet
# 429: Auf der mit EKZ BB6 bezeichnet
# 431: Auf den mit BB7 bezeichneten G
# 432: Auf den mit P BB8 bezeichneten
# 435: Entlang der mit BB9 bezeichnet
# 437: Unter Anwendung von § 4 Abs. 3
# 456: Auf der mit Esp bezeichneten F
# 459: Auf den mit BB1 bezeichneten F
# 0: Unverkäufliches Dienstexemplar
# 1: M A G I S T R A T D E R S T A
# 2: Der Gemeinderat hat in seiner
# 3: Bezirk, Kat. G. Stammersdorf w
# 4: Der bisher gültige Flächenwidm
# 5: Die roten Planzeichen gelten a
# 6: Für die rechtliche Bedeutung d
# 7: September 1996 maßgebend, die
# 8: Für die Querschnitte der Verke
# 9: Seite - 2 -
# 11: Gemäß § 3 Wiener Kleingartenge
# 14: Der Abteilungsleiter: Dipl.-In
# 15: Unverkäufliches Dienstexemplar
# 16: M A G I S T R A T D E R S T A
# 17: Der Gemeinderat hat in seiner
# 18: Bezirk, Kat. G. Leopoldstadt s
# 19: Die roten Planzeichen gelten a
# 20: Für die rechtliche Bedeutung d
# 21: September 1996 maßgebend, die
# 22: Für die Querschnitte der Verke
# 23: Seite - 2 -
# 24: Gemäß § 5 Abs.4 der BO für Wie
# 25: An allen Baulinien ist die Err
# 26: Bauelemente, die der Gliederun
# 27: Der höchste Punkt der zur Ausf
# 28: Für alle Flächen, für die die
# 29: Einfriedungen an seitlichen un
# 30: Besondere Bestimmungen gemäß §
# 35: Seite - 3 -
# 36: In den als Wohnzone gemäß § 7a
# 38: Der Abteilungsleiter: Dipl.-In
# 39: Unverkäufliches Dienstexemplar
# 40: M A G I S T R A T D E R S T A
# 41: Der Gemeinderat hat in seiner
# 42: Bezirk, Kat. G. Neustift am Wa
# 43: Der bisher gültige Flächenwidm
# 44: Die roten Planzeichen gelten a
# 45: Für die rechtliche Bedeutung d
# 46: Für die Querschnitte der Verke
# 47: Bei einer Straßenbreite bis zu
# 48: In der Krottenbachstraße (ONr.
# 49: In der Hartäckerstraße (ONr. 6
# 50: Bestimmungen gemäß §5 Abs. 4 d
# 51: Der höchste Punkt der im Baula
# 52: Soweit die zulässige Gebäudehö
# 53: Nicht bebaute, jedoch bebaubar
# 55: Die mit Nebengebäuden bebaute
# 56: Die Dächer dieser Nebengebäude
# 57: Technische bzw. der Belichtung
# 58: Einfriedungen auf gärtnerisch
# 59: Bestimmungen gemäß §5 Abs. 4 d
# 62: der höchste Punkt des Daches d
# 69: Gemäß §3 des Wiener Kleingarte
# 71: Der Abteilungsleiter: Dipl.-In
# 72: Unverkäufliches Dienstexemplar
# 73: M A G I S T R A T D E R S T A
# 74: Der Gemeinderat hat in seiner
# 75: Der bisher gültige Flächenwidm
# 76: Die roten Planzeichen gelten a
# 77: Für die rechtliche Bedeutung d
# 78: September 1996 maßgebend, die
# 79: Für die Querschnitte der Verke
# 80: In der Semperstraße, Weitlofga
# 81: Bestimmungen gemäß § 4 Abs. 3
# 83: Oberhalb der Garagendecke muss
# 84: Bestimmungen gemäß § 5 Abs. 4
# 85: An den zu öffentlichen Verkehr
# 86: Vorstehende Bauelemente, die d
# 87: Bei den innerhalb des Baulande
# 89: Für alle übrigen Gebäude bis z
# 90: Grad entsprechend dem Stand de
# 91: Technische bzw. der Belichtung
# 92: Nicht bebaute, jedoch bebaubar
# 93: An den zu den Verkehrsflächen
# 94: Seite - 3 - An den zu den Verk
# 95: Die mit Nebengebäuden bebaute
# 96: m2 je Bauplatz betragen.
# 97: Die Dächer dieser Nebengebäude
# 98: Technische bzw. der Belichtung
# 99: Einfriedungen an seitlichen un
# 104: Der höchste Punkt des Daches d
# 106: Der Abteilungsleiter: Dipl.-In
# 107: MAGISTRAT DER STADT WIEN MA 21
# 108: Der Gemeinderat hat in seiner
# 109: Bezirk, Kat. G. Aspern, Stadla
# 110: Die roten Planzeichen gelten a
# 111: die schwarzen Planzeichen beha
# 112: Für die rechtliche Bedeutung d
# 115: Der höchste Punkt des Daches d
# 117: Im Übrigen haben die Planzeich
# 118: Der Abteilungsleiter: Dipl.-In
# 119: Unverkäufliches Dienstexemplar
# 120: M A G I S T R A T D E R S T A
# 121: Der Gemeinderat hat in seiner
# 122: Bezirk, Kat. G. Penzing und Ka
# 123: Der bisher gültige Flächenwidm
# 124: Die roten Planzeichen gelten a
# 125: Für die rechtliche Bedeutung d
# 126: Für die Querschnitte der Verke
# 127: In der Schlossallee und der Ma

# %%
train_data
# Out:
#                                                   Text  Label  \
# 10   Gemäß § 5 (4) der Bauordnung für Wien wird für...   True
# 12   Die mit Eklw/BB2 bezeichnete Fläche ist der Er...   True
# 13   Von der mit Eklw P BB3 bezeichneten Fläche dür...   True
# 31   Auf den mit G/BB1 bezeichneten Flächen ist die...   True
# 32   In den mit BB2 bezeichneten Bereichen sind die...   True
# ..                                                 ...    ...
# 123  Der bisher gültige Flächenwidmungsplan und Beb...  False
# 124  Die roten Planzeichen gelten als neu festgesetzt.  False
# 125  Für die rechtliche Bedeutung der roten Planzei...  False
# 126  Für die Querschnitte der Verkehrsflächen gemäß...  False
# 127  In der Schlossallee und der Mariahilfer Straße...  False
#
#                                                  4lang
# 10   <tuw_nlp.graph.fourlang.FourLang object at 0x7...
# 12   <tuw_nlp.graph.fourlang.FourLang object at 0x7...
# 13   <tuw_nlp.graph.fourlang.FourLang object at 0x7...
# 31   <tuw_nlp.graph.fourlang.FourLang object at 0x7...
# 32   <tuw_nlp.graph.fourlang.FourLang object at 0x7...
# ..                                                 ...
# 123  <tuw_nlp.graph.fourlang.FourLang object at 0x7...
# 124  <tuw_nlp.graph.fourlang.FourLang object at 0x7...
# 125  <tuw_nlp.graph.fourlang.FourLang object at 0x7...
# 126  <tuw_nlp.graph.fourlang.FourLang object at 0x7...
# 127  <tuw_nlp.graph.fourlang.FourLang object at 0x7...
#
# [200 rows x 3 columns]
